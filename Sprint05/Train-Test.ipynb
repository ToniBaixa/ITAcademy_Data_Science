# %% [markdown]
# # Tasca M5 T02

# %% [markdown]
# ### Ex1
# ##### Parteix el conjunt de dades adjunt en train i test. Estudia els dos conjunts per separat, a nivell descriptiu.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random


columnes= ['CRIM', 'ZN', 'INDUS','CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv(r"housing data.csv", names=columnes)

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.isnull().sum()
# Wonderful, no Nulls!
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
y = np.array(df['MEDV'])
X= df.drop('MEDV', axis = 1)
# 40% for test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %% [markdown]
# #### Dades de Train

# %%
# 60% 
X_train.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 198  0.03768  80.0   1.52     0  0.404  7.274   38.3  7.3090    2  329.0
# 145  2.37934   0.0  19.58     0  0.871  6.130  100.0  1.4191    5  403.0
# 158  1.34284   0.0  19.58     0  0.605  6.066  100.0  1.7573    5  403.0
# 150  1.65660   0.0  19.58     0  0.871  6.122   97.3  1.6180    5  403.0
# 250  0.14030  22.0   5.86     0  0.431  6.487   13.0  7.3967    7  330.0
#
#      PTRATIO       B  LSTAT
# 198     12.6  392.20   6.62
# 145     14.7  172.91  27.80
# 158     14.7  353.89   6.43
# 150     14.7  372.80  14.10
# 250     19.1  396.28   5.90

# %%
X_train.shape
# Out:
# (303, 13)

# %%
X_train.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     3.405409   12.077558   11.110000    0.069307    0.556297    6.304604
# std      8.620871   24.446551    7.038224    0.254395    0.117823    0.714118
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.078805    0.000000    4.950000    0.000000    0.449000    5.904500
# 50%      0.253870    0.000000    8.560000    0.000000    0.538000    6.211000
# 75%      3.521480   19.000000   18.100000    0.000000    0.631000    6.676000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    69.315512    3.755173    9.336634  403.498350   18.461056  361.424488
# std     28.498865    2.092059    8.685007  170.651069    2.208863   83.879292
# min      2.900000    1.174200    1.000000  187.000000   12.600000    0.320000
# 25%     44.750000    2.094100    4.000000  276.000000   17.400000  376.075000
# 50%     81.300000    3.215700    5.000000  329.000000   19.100000  391.340000
# 75%     93.950000    4.914950   24.000000  666.000000   20.200000  395.660000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#            LSTAT
# count  303.00000
# mean    12.49901
# std      7.12836
# min      1.73000
# 25%      6.74000
# 50%     11.10000
# 75%     16.92000
# max     36.98000

# %% [markdown]
# #### Dades de Test

# %%
X_test.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 329   0.06724  0.0   3.24     0  0.460  6.333   17.2  5.2146    4  430.0
# 371   9.23230  0.0  18.10     0  0.631  6.216  100.0  1.1691   24  666.0
# 219   0.11425  0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276.0
# 403  24.80170  0.0  18.10     0  0.693  5.349   96.0  1.7028   24  666.0
# 78    0.05646  0.0  12.83     0  0.437  6.232   53.7  5.0141    5  398.0
#
#      PTRATIO       B  LSTAT
# 329     16.9  375.21   7.34
# 371     20.2  366.15   9.53
# 219     16.4  393.74  10.50
# 403     20.2  396.90  19.77
# 78      18.7  386.40  12.34

# %%
# 40% 
X_test.shape
# Out:
# (203, 13)

# %%
X_test.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean     3.924158   10.298030   11.176749    0.068966    0.552304    6.254828
# std      8.584480   21.550966    6.602936    0.254022    0.113159    0.685758
# min      0.013110    0.000000    0.740000    0.000000    0.392000    3.863000
# 25%      0.092590    0.000000    5.860000    0.000000    0.453000    5.877000
# 50%      0.268380    0.000000    9.690000    0.000000    0.532000    6.185000
# 75%      3.959670   12.500000   18.100000    0.000000    0.624000    6.543000
# max     73.534100   95.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    67.469458    3.854552    9.866995  415.310345   18.447291  349.583448
# std     27.651184    2.129718    8.752202  165.497502    2.103069  101.161910
# min      6.000000    1.129600    1.000000  188.000000   12.600000    2.600000
# 25%     45.650000    2.105700    4.000000  287.000000   17.150000  374.110000
# 50%     73.100000    3.199200    5.000000  358.000000   19.000000  391.700000
# 75%     94.400000    5.408300   24.000000  666.000000   20.200000  396.900000
# max    100.000000   10.710300   24.000000  711.000000   21.200000  396.900000
#
#             LSTAT
# count  203.000000
# mean    12.883005
# std      7.171432
# min      1.920000
# 25%      7.380000
# 50%     11.640000
# 75%     17.025000
# max     37.970000

# %% [markdown]
# ### Ex2
# ##### Aplica algun procés de transformació (estandarditzar les dades numèriques, crear columnes dummies, polinomis...).

# %%
# Polynomial Transformation
from sklearn.preprocessing import PolynomialFeatures
#transform to include some X2...
transformer = PolynomialFeatures(degree=2, include_bias=False)

# %%
# modified array
X_train_trans = transformer.fit_transform(X_train)
X_test_trans = transformer.fit_transform(X_test)
print (X_train_trans)
# Out:
# [[3.76800000e-02 8.00000000e+01 1.52000000e+00 ... 1.53820840e+05
#   2.59636400e+03 4.38244000e+01]
#  [2.37934000e+00 0.00000000e+00 1.95800000e+01 ... 2.98978681e+04
#   4.80689800e+03 7.72840000e+02]
#  [1.34284000e+00 0.00000000e+00 1.95800000e+01 ... 1.25238132e+05
#   2.27551270e+03 4.13449000e+01]
#  ...
#  [1.50980000e-01 0.00000000e+00 1.00100000e+01 ... 1.55638140e+05
#   4.06345300e+03 1.06090000e+02]
#  [2.29270000e-01 0.00000000e+00 6.91000000e+00 ... 1.54244708e+05
#   7.38351200e+03 3.53440000e+02]
#  [1.39140000e-01 0.00000000e+00 4.05000000e+00 ... 1.57529610e+05
#   5.83046100e+03 2.15796100e+02]]

# %% [markdown]
# ### Ex3
# ##### Resumeix les noves columnes generades de manera estadística i gràfica

# %%
# check correlation
import seaborn as sns
import matplotlib.pyplot as plt
df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(df.corr() , annot=True , lw=1 )
# Out:
# <AxesSubplot:>
