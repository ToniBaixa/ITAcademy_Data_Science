# %% [markdown]
# # Tasca M5 T01

# %% [markdown]
# ### Ex1
# ##### Descarrega el dataset adjunt de dades oficials de la UEFA i selecciona un atribut del conjunt de dades. Calcula el p-valor i digues si rebutja la hipòtesi nul·la agafant un alfa de 5%.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random


df = pd.read_csv("Lligues_europees_UEFA.csv")

df.head()
# Out:
#    Rk  GA  GD  Pts  Pts/G    xG   xGA   xGD  xGD/90     Last 5  ...  \
# 0   1  24  72   90   2.43  86.1  26.8  59.3    1.60  W W W W D  ...
# 1   2  24  65   86   2.39  84.6  33.1  51.4    1.43  W W W D W  ...
# 2   3  31  49   85   2.30  73.0  45.8  27.2    0.73  W W L W D  ...
# 3   4  37  60   77   2.26  88.1  37.1  51.0    1.50  W W L D D  ...
# 4   5  36  49   83   2.24  71.6  38.1  33.4    0.90  W D D D W  ...
#
#              Squad          Top Team Scorer        Goalkeeper Country LgRk  \
# 0  Manchester City     Kevin De Bruyne - 15           Ederson     ENG    1
# 1        Liverpool       Mohamed Salah - 22           Alisson     ENG    2
# 2      Real Madrid       Karim Benzema - 27  Thibaut Courtois     ESP    1
# 3    Bayern Munich  Robert Lewandowski - 35      Manuel Neuer     GER    1
# 4        Paris S-G       Kylian Mbapp� - 25      Keylor Navas     FRA    1
#
#    MP   W  D  L  GF
# 0  37  28  6  3  96
# 1  36  26  8  2  89
# 2  37  26  7  4  80
# 3  34  24  5  5  97
# 4  37  25  8  4  85
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               Rk         GA         GD        Pts      Pts/G         xG  \
# count  98.000000  98.000000  98.000000  98.000000  98.000000  98.000000
# mean   49.500000  50.877551   0.000000  49.734694   1.370204  48.653061
# std    28.434134  13.634602  26.501896  16.166371   0.443903  12.453950
# min     1.000000  24.000000 -56.000000  18.000000   0.530000  28.200000
# 25%    25.250000  40.000000 -17.750000  37.000000   1.000000  39.100000
# 50%    49.500000  50.000000  -1.000000  46.000000   1.300000  46.450000
# 75%    73.750000  59.000000  17.250000  61.750000   1.695000  55.550000
# max    98.000000  89.000000  72.000000  90.000000   2.430000  88.100000
#
#              xGA        xGD     xGD/90    Attendance       LgRk         MP  \
# count  98.000000  98.000000  98.000000     98.000000  98.000000  98.000000
# mean   48.645918  -0.005102   0.000918  24239.857143  10.316327  36.306122
# std     9.812481  19.992506   0.551414  14874.171842   5.706926   1.152390
# min    26.800000 -40.400000  -1.090000   5870.000000   1.000000  34.000000
# 25%    41.300000 -13.575000  -0.365000  12355.500000   5.250000  36.000000
# 50%    47.750000  -1.100000  -0.030000  20491.000000  10.000000  37.000000
# 75%    54.700000  12.800000   0.355000  32382.000000  15.000000  37.000000
# max    73.300000  59.300000   1.600000  73150.000000  20.000000  37.000000
#
#                W          D         L         GF
# count  98.000000  98.000000  98.00000  98.000000
# mean   13.448980   9.408163  13.44898  50.877551
# std     5.747474   2.903381   5.12347  16.102933
# min     3.000000   3.000000   2.00000  23.000000
# 25%     9.000000   7.000000  10.00000  39.000000
# 50%    13.000000   9.000000  13.00000  47.000000
# 75%    17.000000  11.000000  17.00000  60.000000
# max    28.000000  16.000000  26.00000  97.000000

# %%
test= df[1:20]
test.head(20)
# Out:
#     Rk  GA  GD  Pts  Pts/G    xG   xGA   xGD  xGD/90     Last 5  ...  \
# 1    2  24  65   86   2.39  84.6  33.1  51.4    1.43  W W W D W  ...
# 2    3  31  49   85   2.30  73.0  45.8  27.2    0.73  W W L W D  ...
# 3    4  37  60   77   2.26  88.1  37.1  51.0    1.50  W W L D D  ...
# 4    5  36  49   83   2.24  71.6  38.1  33.4    0.90  W D D D W  ...
# 5    6  31  35   83   2.24  60.0  34.4  25.6    0.69  W W W W W  ...
# 6    7  32  49   81   2.19  78.1  38.2  39.9    1.08  W L W W W  ...
# 7    8  31  40   76   2.05  58.5  29.9  28.6    0.77  D L W W W  ...
# 8    9  52  33   69   2.03  62.8  43.2  19.6    0.58  W L L W W  ...
# 9   10  36  32   73   1.97  61.3  35.2  26.1    0.71  L W W W D  ...
# 10  11  31  42   70   1.94  63.2  34.9  28.4    0.79  W D L D W  ...
# 11  12  33  22   69   1.92  50.5  35.4  15.2    0.42  W D W W L  ...
# 12  13  47  33   64   1.88  63.3  43.1  20.2    0.59  L W W W W  ...
# 13  14  38  25   68   1.84  56.8  39.7  17.1    0.46  W W W W W  ...
# 14  15  40  24   68   1.84  61.5  39.0  22.5    0.61  D W D W W  ...
# 15  16  38  21   68   1.84  56.6  39.2  17.4    0.47  W W L W L  ...
# 16  17  42  21   68   1.84  51.0  30.9  20.1    0.56  D L W W D  ...
# 17  18  45  11   66   1.83  56.3  44.0  12.2    0.34  W W W W L  ...
# 18  19  30  22   67   1.81  42.0  36.8   5.2    0.14  W D D D D  ...
# 19  20  38  42   65   1.76  61.2  39.2  22.0    0.60  L W W L W  ...
#
#               Squad                Top Team Scorer             Goalkeeper  \
# 1         Liverpool             Mohamed Salah - 22                Alisson
# 2       Real Madrid             Karim Benzema - 27       Thibaut Courtois
# 3     Bayern Munich        Robert Lewandowski - 35           Manuel Neuer
# 4         Paris S-G             Kylian Mbapp� - 25           Keylor Navas
# 5             Milan               Rafael Le�o - 11           Mike Maignan
# 6             Inter          Lautaro Mart�nez - 21       Samir Handanovi?
# 7            Napoli            Victor Osimhen - 14           David Ospina
# 8          Dortmund            Erling Haaland - 22           Gregor Kobel
# 9         Barcelona             Memphis Depay - 12  Marc-Andr� ter Stegen
# 10          Chelsea               Mason Mount - 11          Edouard Mendy
# 11         Juventus              Paulo Dybala - 10      Wojciech Szcz?sny
# 12       Leverkusen             Patrik Schick - 24         Luk�� Hr�deck?
# 13           Monaco         Wissam Ben Yedder - 24        Alexander N�bel
# 14        Tottenham             Son Heung-min - 21            Hugo Lloris
# 15        Marseille             Dimitri Payet - 12              Pau L�pez
# 16  Atl�tico Madrid  �ngel Correa Luis Su�rez - 11              Jan Oblak
# 17          Arsenal               Bukayo Saka - 11         Aaron Ramsdale
# 18          Sevilla                   Rafa Mir - 9         Yassine Bounou
# 19           Rennes            Martin Terrier - 21           Alfred Gomis
#
#    Country LgRk  MP   W   D   L  GF
# 1      ENG    2  36  26   8   2  89
# 2      ESP    1  37  26   7   4  80
# 3      GER    1  34  24   5   5  97
# 4      FRA    1  37  25   8   4  85
# 5      ITA    1  37  25   8   4  66
# 6      ITA    2  37  24   9   4  81
# 7      ITA    3  37  23   7   7  71
# 8      GER    2  34  22   3   9  85
# 9      ESP    2  37  21  10   6  68
# 10     ENG    3  36  20  10   6  73
# 11     ITA    4  36  20   9   7  55
# 12     GER    3  34  19   7   8  80
# 13     FRA    2  37  20   8   9  63
# 14     ENG    4  37  21   5  11  64
# 15     FRA    3  37  20   8   9  59
# 16     ESP    3  37  20   8   9  63
# 17     ENG    5  36  21   3  12  56
# 18     ESP    4  37  17  16   4  52
# 19     FRA    4  37  20   5  12  80
#
# [19 rows x 21 columns]

# %%
# python -m pip install --user numpy scipy matplotlib ipython jupyter pandas sympy nose
from scipy.stats import shapiro
stat, p = shapiro(test['W'])
print('stat=%.3f, p-valor=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')

print('No la rebutja')
# Out:
# stat=0.919, p-valor=0.110
# Probably Gaussian
# No la rebutja

# %% [markdown]
# ### Ex2
# ##### Amb el mateix dataset selecciona dos altres atributs del conjunt de dades. Calcula els p-valors i digues si rebutgen la hipòtesi nul·la agafant un alfa de 5%
# ##### Creem 2 samples i anem a comprovar si són differents

# %%
sample1= df[50:60]
sample2= df[100:110]
# Ho = equal
# H1 = unequal


# Student's t-test
from scipy.stats import ttest_ind
stat, p = ttest_ind(sample1['xGD'], sample2['xGD'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=nan, p=nan
# Probably different distributions

# %% [markdown]
# ### Ex3
# ##### Continua amb el conjunt de dades adjunt i selecciona tres atributs del conjunt de dades. Calcula el p-valor i digues si rebutja la hipòtesi nul·la agafant un alfa de 5%

# %%
# Analysis of Variance Test (ANOVA)
from scipy.stats import f_oneway
data1 = sample1['GF']
data2 = sample2['GF']
data3 = sample1['GA']
stat, p = f_oneway(data1, data2, data3)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=nan, p=nan
# Probably different distributions
# C:\Users\Toni Andreu\AppData\Roaming\Python\Python39\site-packages\scipy\stats\stats.py:3621: F_onewayBadInputSizesWarning: at least one input has length 0
#   warnings.warn(F_onewayBadInputSizesWarning('at least one input '
